# %% [markdown]
# # CSV_READER

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/Pandas/refs/heads/main/superstore_data.csv'
dados_mercado= pd.read_csv(url , sep=',')
dados_mercado.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
dado_selecao = pd.read_csv(url, usecols=['Id', 'Year_Birth', 'Income'])
dado_selecao
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# Também funciona indices

# %%
dado_selecao = pd.read_csv(url, usecols=[0, 1, 4])
dado_selecao
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %%
dado_selecao.to_csv('clientes_mercado.csv', index=False)

# %%
clients_mercado= pd.read_csv('/content/clientes_mercado.csv')

# %% [markdown]
# #Planilhas Reader

# %%
url_sheets = 'https://github.com/alura-cursos/Pandas/raw/refs/heads/main/emissoes_CO2.xlsx?=True'

# %%
dados_co2= pd.read_excel(url_sheets)

# %%
dados_co2.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total  Carvão  Oléo  Gás  Cimento  \
# 0  Afeganistão                AFG  1750    0.0     NaN   NaN  NaN      NaN
# 1  Afeganistão                AFG  1751    0.0     NaN   NaN  NaN      NaN
# 2  Afeganistão                AFG  1752    0.0     NaN   NaN  NaN      NaN
# 3  Afeganistão                AFG  1753    0.0     NaN   NaN  NaN      NaN
# 4  Afeganistão                AFG  1754    0.0     NaN   NaN  NaN      NaN
#
#    Queima  Outro  Per Capita
# 0     NaN    NaN         NaN
# 1     NaN    NaN         NaN
# 2     NaN    NaN         NaN
# 3     NaN    NaN         NaN
# 4     NaN    NaN         NaN

# %%
pd.ExcelFile(url_sheets).sheet_names
# Out:
# ['emissoes_C02', 'emissoes_percapita', 'fontes']

# %%
percapita =pd.read_excel(url_sheets,sheet_name='emissoes_percapita')

# %%
fontes = pd.read_excel(url_sheets,sheet_name='fontes')

# %% [markdown]
# usecols

# %%
intervalo = pd.read_excel(url_sheets, usecols='A:D')

# %%
intervalo.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total
# 0  Afeganistão                AFG  1750    0.0
# 1  Afeganistão                AFG  1751    0.0
# 2  Afeganistão                AFG  1752    0.0
# 3  Afeganistão                AFG  1753    0.0
# 4  Afeganistão                AFG  1754    0.0

# %%
intervalo2 = pd.read_excel(url_sheets, usecols='A:D',nrows=10)

# %%
intervalo2
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total
# 0  Afeganistão                AFG  1750      0
# 1  Afeganistão                AFG  1751      0
# 2  Afeganistão                AFG  1752      0
# 3  Afeganistão                AFG  1753      0
# 4  Afeganistão                AFG  1754      0
# 5  Afeganistão                AFG  1755      0
# 6  Afeganistão                AFG  1756      0
# 7  Afeganistão                AFG  1757      0
# 8  Afeganistão                AFG  1758      0
# 9  Afeganistão                AFG  1759      0

# %%
percapita.to_excel('co2_percapita.xlsx',index=False)

# %% [markdown]
# From google sheets

# %%
https://docs.google.com/spreadsheets/d/12Oy0VxoI0gfb2ejkc84boR_Rjo9m-p1pLWJYf0UiIVw/edit?usp=sharing

# %%
sheet_id = '12Oy0VxoI0gfb2ejkc84boR_Rjo9m-p1pLWJYf0UiIVw'

# %%
url_google = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

# %%
dados_co2_google= pd.read_csv(url_google)
dados_co2.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total  Carvão  Oléo  Gás  Cimento  \
# 0  Afeganistão                AFG  1750    0.0     NaN   NaN  NaN      NaN
# 1  Afeganistão                AFG  1751    0.0     NaN   NaN  NaN      NaN
# 2  Afeganistão                AFG  1752    0.0     NaN   NaN  NaN      NaN
# 3  Afeganistão                AFG  1753    0.0     NaN   NaN  NaN      NaN
# 4  Afeganistão                AFG  1754    0.0     NaN   NaN  NaN      NaN
#
#    Queima  Outro  Per Capita
# 0     NaN    NaN         NaN
# 1     NaN    NaN         NaN
# 2     NaN    NaN         NaN
# 3     NaN    NaN         NaN
# 4     NaN    NaN         NaN

# %%
sheet_id = '12Oy0VxoI0gfb2ejkc84boR_Rjo9m-p1pLWJYf0UiIVw'
sheet_name = 'emissoes_percapita'
url_pagina = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'
dados_emissoes_percapito = pd.read_csv(url_pagina)
dados_emissoes_percapito.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano Total Carvão Óleo  Gás Cimento Queima  \
# 0  Afeganistão                AFG  1750   NaN    NaN  NaN  NaN     NaN    NaN
# 1  Afeganistão                AFG  1751   NaN    NaN  NaN  NaN     NaN    NaN
# 2  Afeganistão                AFG  1752   NaN    NaN  NaN  NaN     NaN    NaN
# 3  Afeganistão                AFG  1753   NaN    NaN  NaN  NaN     NaN    NaN
# 4  Afeganistão                AFG  1754   NaN    NaN  NaN  NaN     NaN    NaN
#
#    Outro
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %% [markdown]
# #JSON_FILES

# %%
import pandas as pd

# %%
import json

# %%
with open('/content/pacientes_2.json','r') as file :
  dados_pacientes = json.loads(file.read())

# %%
dados_pacientes
# Out:
# {'Pesquisa': 'Principais Indicadores de Doenca Cardiaca',
#  'Ano': 2020,
#  'Pacientes': [{'ID': '01',
#    'Faixa_etaria': '55-59',
#    'Sexo_biologico': 'Feminino',
#    'Raça': 'Branca',
#    'IMC': 16.6,
#    'Fumante': 'Sim',
#    'Consumo_alcool': 'Nao',
#    'Saude_fisica': 3,
#    'Saude_mental': 30,
#    'Dificuldade_caminhar': 'Nao',
#    'Atividade_fisica': 'Sim',
#    'Saude_geral': 'Muito boa',
#    'Horas_sono': 5,
#    'Problemas_saude': ['Diabetes', 'Asma', 'Cancer_pele']},
#   {'ID': '02',
#    'Faixa_etaria': '80 ou +',
#    'Sexo_biologico': 'Feminino',
#    'Raça': 'Branca',
#    'IMC': 20.34,
#    'Fumante': 'Nao',
#    'Consumo_alcool': 'Nao',
#    'Saude_fisica': 0,
#    'Saude_mental': 0,
#    'Dificuldade_caminhar': 'Nao',
#    'Atividade_fisica': 'Sim',
#    'Saude_geral': 'Muito boa',
#    'Horas_sono': 7,
#    'Problemas_saude': ['AVC']},
#   {'ID': '03',
#    'Faixa_etaria': '65-69',
#    'Sexo_biologico': 'Masculino',
#    'Raça': 'Branca',
# ...

# %% [markdown]
# olhando ai acima ja sabemos que o paciente vai ta aninhado e precisamos concertar ele e nao so isso temos que aparecer o json de pesquisa e de ano. Por isso preisamos adicionar esse meta, e o record_path é a coisa que queremos desaninhar

# %%
df_normalizado = pd.json_normalize(dados_pacientes,record_path='Pacientes',meta=['Pesquisa','Ano'])

# %%
df_normalizado.to_json('Historico_pacientes_normalizados.json')

# %%
pd.read_json('/content/Historico_pacientes_normalizados.json')
# Out:
#    ID Faixa_etaria Sexo_biologico    Raça    IMC Fumante Consumo_alcool  \
# 0   1        55-59       Feminino  Branca  16.60     Sim            Nao
# 1   2      80 ou +       Feminino  Branca  20.34     Nao            Nao
# 2   3        65-69      Masculino  Branca  26.58     Sim            Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Atividade_fisica  \
# 0             3            30                  Nao              Sim
# 1             0             0                  Nao              Sim
# 2            20            30                  Nao              Sim
#
#   Saude_geral  Horas_sono                Problemas_saude  \
# 0   Muito boa           5  [Diabetes, Asma, Cancer_pele]
# 1   Muito boa           7                          [AVC]
# 2   Muito boa           8               [diabetes, Asma]
#
#                                     Pesquisa   Ano
# 0  Principais Indicadores de Doenca Cardiaca  2020
# 1  Principais Indicadores de Doenca Cardiaca  2020
# ...

# %% [markdown]
# #HTLM_READER

# %%
import pandas as pd

# %%
dados_html = pd.read_html('/content/filmes_wikipedia.html')

# %%
dados_html
# Out:
# [       0                      1
#  0   1998             100 Movies
#  1   1999              100 Stars
#  2   2000             100 Laughs
#  3   2001            100 Thrills
#  4   2002           100 Passions
#  5   2003  100 Heroes & Villains
#  6   2004              100 Songs
#  7   2005       100 Movie Quotes
#  8   2005              25 Scores
#  9   2006             100 Cheers
#  10  2006            25 Musicals
#  11  2007   100 Movies (Updated)
#  12  2008        AFI's 10 Top 10
#  13   vte                    vte,
#                              Film  Release year              Director  \
#  0                   Citizen Kane          1941          Orson Welles
#  1                     Casablanca          1942        Michael Curtiz
#  2                  The Godfather          1972  Francis Ford Coppola
#  3             Gone with the Wind          1939        Victor Fleming
#  4             Lawrence of Arabia          1962            David Lean
# ...

# %%
type(dados_html)
# Out:
# list

# %%
len(dados_html)
# Out:
# 3

# %%
top_filmes = dados_html[1]

# %%
top_filmes
# Out:
#                             Film  Release year              Director  \
# 0                   Citizen Kane          1941          Orson Welles
# 1                     Casablanca          1942        Michael Curtiz
# 2                  The Godfather          1972  Francis Ford Coppola
# 3             Gone with the Wind          1939        Victor Fleming
# 4             Lawrence of Arabia          1962            David Lean
# ..                           ...           ...                   ...
# 95                 The Searchers          1956             John Ford
# 96              Bringing Up Baby          1938          Howard Hawks
# 97                    Unforgiven          1992        Clint Eastwood
# 98  Guess Who's Coming to Dinner          1967        Stanley Kramer
# 99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                       Production companies  Rank
# 0                       RKO Radio Pictures     1
# ...

# %% [markdown]
# Editando html é atraves de um csv, foi a maneira que ela abordou, ou seja, precisamos transformar esse dataframe top filmes em um csv. Para uma pessoa mexeer nele no excel, por exemplo.

# %%
top_filmes.to_html('top_filmes.html') #so para vizualização web
top_filmes.to_csv('top_filmes_1998.csv', sep=',',index=False)

# %% [markdown]
# #XML

# %%
import pandas as pd

# %%
dados_imdb= pd.read_xml('/content/imdb_top_1000.xml')

# %%
dados_imdb
# Out:
#      index                                        Poster_Link  \
# 0        0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1        1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2        2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3        3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4        4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..     ...                                                ...
# 995    995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996    996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997    997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998    998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999    999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# ...

# %%
dados_imdb.to_xml('filmes_imbd.xml')

# %% [markdown]
# #Trabalhando com banco de dados

# %%
import sqlalchemy

# %%
from sqlalchemy import create_engine, MetaData, table,inspect

# %%
engine = create_engine('sqlite:///: memory :')

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/Pandas/refs/heads/main/clientes_banco.csv'

# %%
import pandas as pd

# %%
dados = pd.read_csv(url)

# %%
dados.head()
# Out:
#    ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0     5008804     32   Ensino superior  União-estável                2
# 1     5008805     32   Ensino superior  União-estável                2
# 2     5008806     58      Ensino médio         Casado                2
# 3     5008808     52      Ensino médio       Solteiro                1
# 4     5008809     52      Ensino médio       Solteiro                1
#
#     Categoria_de_renda   Ocupacao  Anos_empregado  Rendimento_anual  \
# 0            Empregado      Outro              12          427500.0
# 1            Empregado      Outro              12          427500.0
# 2            Empregado  Segurança               3          112500.0
# 3  Associado comercial     Vendas               8          270000.0
# 4  Associado comercial     Vendas               8          270000.0
#
#    Tem_carro                   Moradia
# 0          1       Apartamento alugado
# 1          1       Apartamento alugado
# ...

# %%
dados.to_sql('Clientes',engine,index=False)
# Out:
# 438463

# %%
inspector = inspect(engine)

# %%
print(inspector.get_table_names())
# Out:
# ['Clientes']

# %% [markdown]
# query

# %%
query = 'SELECT * FROM Clientes WHERE Categoria_de_renda = "Empregado"'

# %%
empregados =  pd.read_sql(query,engine)
empregados.head()
# Out:
#    ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0     5008804     32   Ensino superior  União-estável                2
# 1     5008805     32   Ensino superior  União-estável                2
# 2     5008806     58      Ensino médio         Casado                2
# 3     5008815     46   Ensino superior         Casado                2
# 4     5112956     46   Ensino superior         Casado                2
#
#   Categoria_de_renda       Ocupacao  Anos_empregado  Rendimento_anual  \
# 0          Empregado          Outro              12          427500.0
# 1          Empregado          Outro              12          427500.0
# 2          Empregado      Segurança               3          112500.0
# 3          Empregado  Contabilidade               2          270000.0
# 4          Empregado  Contabilidade               2          270000.0
#
#    Tem_carro                   Moradia
# 0          1       Apartamento alugado
# ...

# %%
empregados.to_sql('empregados',con=engine,index=False)
# Out:
# 226059

# %%
pd.read_sql_table('empregados',engine, columns= ['ID_Cliente','Grau_escolaridade','Rendimento_anual'])
# Out:
#         ID_Cliente Grau_escolaridade  Rendimento_anual
# 0          5008804   Ensino superior          427500.0
# 1          5008805   Ensino superior          427500.0
# 2          5008806      Ensino médio          112500.0
# 3          5008815   Ensino superior          270000.0
# 4          5112956   Ensino superior          270000.0
# ...            ...               ...               ...
# 226054     6837905      Ensino médio          355050.0
# 226055     6837906      Ensino médio          355050.0
# 226056     6839936      Ensino médio          135000.0
# 226057     6840222      Ensino médio          103500.0
# 226058     6842885      Ensino médio          121500.0
#
# [226059 rows x 3 columns]

# %%
from sqlalchemy import text

# %%
query = 'DELETE FROM clientes WHERE ID_Cliente=5008804'
with engine.connect() as conn:
    result = conn.execute(text(query))
    conn.commit()

# %% [markdown]
# Atualização da escolaridade do fulano

# %%
query = 'UPDATE clientes SET Grau_escolaridade="Ensino superior" WHERE ID_Cliente=5008808'
with engine.connect() as conn:
    result = conn.execute(text(query))
    conn.commit()

# %% [markdown]
# Atualizar o registro do cliente de ID 6840104 que teve o rendimento anual alterado para 300000.

# %%
query2 = ' UPDATE clientes SET Rendimento_anual	= 300000 WHERE ID_Cliente = 6840104'
with engine.connect() as conn2:
  result2 = conn2.execute(text(query2))
  conn2.commit()

# %%
empregados_2 = pd.read_sql(query2,engine)
empregados_2
# Out:
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# /tmp/ipython-input-32-1187711722.py in <cell line: 0>()
# ----> 1 empregados_2 = pd.read_sql(query2,engine)
#       2 empregados_2
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     732             )
#     733         else:
# --> 734             return pandas_sql.read_query(
#     735                 sql,
#     736                 index_col=index_col,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1835         """
#    1836         result = self.execute(sql, params)
# -> 1837         columns = result.keys()
#    1838
#    1839         if chunksize is not None:
#
# ...

# %% [markdown]
# Excluir o registro do cliente de ID 5008809, pois essa pessoa não possui mais conta na instituição financeira.

# %% [markdown]
# Criar um novo registro de cliente seguindo as especificações abaixo:
# ID_Cliente: 6850985
# Idade: 33
# Grau_escolaridade: Doutorado
# Estado_civil: Solteiro
# Tamanho_familia: 1
# Categoria_de_renda: Empregado
# Ocupacao: TI
# Anos_empregado: 2
# Rendimento_anual: 290000
# Tem_carro: 0
# Moradia: Casa/apartamento próprio

# %% [markdown]
# #Desafios

# %%
import chardet

# %% [markdown]
# Verificar a codificação do arquivo

# %%
with open('/content/dados_sus.csv', 'rb') as file:
  print(chardet.detect(file.read()))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3108448733.py in <cell line: 0>()
# ----> 1 with open('/content/dados_sus.csv', 'rb') as file:
#       2   print(chardet.detect(file.read()))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/dados_sus.csv'

# %% [markdown]
# Verifique se o arquivo CSV está separado por vírgula ou ponto e vírgula.

# %%
url_des = '/content/dados_sus.csv'
dados_sus = pd.read_csv(url_des,encoding='ISO-8859-1',sep=';', skiprows=3,skipfooter=9, engine='python')
dados_sus
# Out:
#    Unidade da Federação      2008/Jan      2008/Fev      2008/Mar  \
# 0              Rondônia    1388528,39    2931283,42    1541682,52
# 1                  Acre     902416,00    1497206,26    1794028,48
# 2              Amazonas    4735529,42    7118990,57    8196635,49
# 3               Roraima     657889,53     777939,31     718688,03
# 4                  Pará   18864744,11   19553758,20   21937342,70
# 5                 Amapá    1120973,34    1268740,33     974651,24
# 6             Tocantins    3441592,69    4985688,85    6205612,60
# 7              Maranhão   10723506,39   13559679,41   13985142,36
# 8                 Piauí    7985142,43   10079928,25   10298372,45
# 9                 Ceará   15539821,90   25735101,55   28724625,75
# 10  Rio Grande do Norte    5947814,08    9509755,83   10352238,59
# 11              Paraíba   10723002,45   11386274,47   12053643,87
# 12           Pernambuco   14393949,89   24181400,95   29991302,71
# ...

# %% [markdown]
# desafio_sheets-google

# %%
https://docs.google.com/spreadsheets/d/1pvBoLyX8kP0TjtUbadVMGdTl4yzm6bHMThhPiqCVtpw/edit?usp=sharing

# %%
sheet_id_des='1pvBoLyX8kP0TjtUbadVMGdTl4yzm6bHMThhPiqCVtpw'
url_des_google=f'https://docs.google.com/spreadsheets/d/{sheet_id_des}/gviz/tq?tqx=out:csv&sheet'
dados_co2_desafio = pd.read_csv(url_des_google)

# %%
dados_co2_desafio.to_csv('dados_desafio_Co2.csv',index=False)

# %% [markdown]
# Json_desafio

# %% [markdown]
# requests - acessar api's

# %%
import json
import requests

# %%
dados_usuarios = requests.get('https://jsonplaceholder.typicode.com/users')
resultado = json.loads(dados_usuarios.text)

# %% [markdown]
# ele so ler com .text

# %%
dados_usuarios_normalizados = pd.json_normalize(resultado,sep='_')

# %%
dados_usuarios_normalizados
# Out:
#    id                      name          username                      email  \
# 0   1             Leanne Graham              Bret          Sincere@april.biz
# 1   2              Ervin Howell         Antonette          Shanna@melissa.tv
# 2   3          Clementine Bauch          Samantha         Nathan@yesenia.net
# 3   4          Patricia Lebsack          Karianne  Julianne.OConner@kory.org
# 4   5          Chelsey Dietrich            Kamren   Lucio_Hettinger@annie.ca
# 5   6      Mrs. Dennis Schulist  Leopoldo_Corkery    Karley_Dach@jasper.info
# 6   7           Kurtis Weissnat      Elwyn.Skiles     Telly.Hoeger@billy.biz
# 7   8  Nicholas Runolfsdottir V     Maxime_Nienow       Sherwood@rosamond.me
# 8   9           Glenna Reichert          Delphine    Chaim_McDermott@dana.io
# 9  10        Clementina DuBuque    Moriah.Stanton     Rey.Padberg@karina.biz
#
#                    phone        website     address_street address_suite  \
# ...

# %% [markdown]
# Desafio HTML

# %%
dados_wiki = pd.read_html('/content/Lista de países por população.html')

# %%
len(dados_wiki)
# Out:
# 3

# %%
planilha_wiki=dados_wiki[0]
# Out:
#      Unnamed: 0 Posição    País (ou território dependente) Estimativa da ONU  \
# 0           NaN       1                              Índia     1 417 492 000
# 1           NaN       2                      China[nota 1]     1.407.934.000
# 2           NaN       3                     Estados Unidos       342.181.000
# 3           NaN       4                          Indonésia       285.783.000
# 4           NaN       5                          Paquistão       256 204 000
# ..          ...     ...                                ...               ...
# 245         NaN       –     Ilha de Ascensão (Reino Unido)             1 100
# 246         NaN     195                           Vaticano               879
# 247         NaN       –  Ilhas Cocos (Keeling) (Austrália)               605
# 248         NaN       –     Tristão da Cunha (Reino Unido)               264
# 249         NaN       –       Ilhas Pitcairn (Reino Unido)                67
#
# ...

# %%
dados_paises = planilha_wiki[['País (ou território dependente)','Estimativa da ONU']]

# %%
dados_paises
# Out:
#        País (ou território dependente) Estimativa da ONU
# 0                                Índia     1 417 492 000
# 1                        China[nota 1]     1.407.934.000
# 2                       Estados Unidos       342.181.000
# 3                            Indonésia       285.783.000
# 4                            Paquistão       256 204 000
# ..                                 ...               ...
# 245     Ilha de Ascensão (Reino Unido)             1 100
# 246                           Vaticano               879
# 247  Ilhas Cocos (Keeling) (Austrália)               605
# 248     Tristão da Cunha (Reino Unido)               264
# 249       Ilhas Pitcairn (Reino Unido)                67
#
# [250 rows x 2 columns]

# %%
dados_paises.to_html('dados_paises.html', index= False)

# %%
dados_paises.to_csv('dados_paises.csv', index=False)

# %%
pd.read_csv('/content/dados_paises.csv')
# Out:
#        País (ou território dependente) Estimativa da ONU
# 0                                Índia     1 417 492 000
# 1                        China[nota 1]     1.407.934.000
# 2                       Estados Unidos       342.181.000
# 3                            Indonésia       285.783.000
# 4                            Paquistão       256 204 000
# ..                                 ...               ...
# 245     Ilha de Ascensão (Reino Unido)             1 100
# 246                           Vaticano               879
# 247  Ilhas Cocos (Keeling) (Austrália)               605
# 248     Tristão da Cunha (Reino Unido)               264
# 249       Ilhas Pitcairn (Reino Unido)                67
#
# [250 rows x 2 columns]

# %%
import pandas as pd

# %%
url_desafio = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/clientes_banco.csv'

# %%
import sqlalchemy

# %%
from sqlalchemy import create_engine,MetaData, table,inspect, text

# %%
engine=create_engine('sqlite:///: memory:')

# %%
dados_cvs_clientes = pd.read_csv(url_desafio)

# %%
dados_cvs_clientes
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008809     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438458     6840104     62      Ensino médio     Divorciado                1
# 438459     6840222     43      Ensino médio       Solteiro                1
# 438460     6841878     22   Ensino superior       Solteiro                1
# 438461     6842765     59      Ensino médio         Casado                2
# 438462     6842885     51      Ensino médio         Casado                2
#
# ...

# %% [markdown]
# Perfeito, agora que voce leu os arquivos, vamos transformar ele em um banco de dados sql

# %%
dados_clientes_sql = dados_cvs_clientes.to_sql('costumers',engine,index = False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-33-1560193310.py in <cell line: 0>()
# ----> 1 dados_clientes_sql = dados_cvs_clientes.to_sql('costumers',engine,index = False)
#
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    3085         from pandas.io import sql
#    3086
# -> 3087         return sql.to_sql(
#    3088             self,
#    3089             name,
#
# ...

# %%
inspector = inspect(engine)

# %% [markdown]
# se vc quer obter agora informação sobre a tabela vc tem que operar com a engine

# %%
print(inspector.get_table_names())
# Out:
# ['Clientes', 'costumers']

# %%
dados_clientes_sql
# Out:
# 438463

# %% [markdown]
# Atualizar o registro do cliente de ID 6840104 que teve o rendimento anual alterado para 300000.

# %%
query_1_desafio = "UPDATE costumers SET Rendimento_anual = 300000 WHERE ID_Cliente = 6840104"

# %% [markdown]
# applying the query

# %%
with engine.connect() as conn:
  result =conn.execute(text(query_1_desafio))
  conn.commit()

# %%
dados_cvs_clientes
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008809     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438458     6840104     62      Ensino médio     Divorciado                1
# 438459     6840222     43      Ensino médio       Solteiro                1
# 438460     6841878     22   Ensino superior       Solteiro                1
# 438461     6842765     59      Ensino médio         Casado                2
# 438462     6842885     51      Ensino médio         Casado                2
#
# ...

# %% [markdown]
# Excluir o registro do cliente de ID 5008809, pois essa pessoa não possui mais conta na instituição financeira.

# %% [markdown]
# Criar um novo registro de cliente seguindo as especificações abaixo:
# ID_Cliente: 6850985
# Idade: 33
# Grau_escolaridade: Doutorado
# Estado_civil: Solteiro
# Tamanho_familia: 1
# Categoria_de_renda: Empregado
# Ocupacao: TI
# Anos_empregado: 2
# Rendimento_anual: 290000
# Tem_carro: 0
# Moradia: Casa/apartamento próprio
