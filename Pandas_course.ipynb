# %% [markdown]
# bloco 1

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
dados = pd.read_csv(url,sep=';')

# %% [markdown]
# selecionando partes das tabela

# %%
dados.head() #o defauld desse amigão é 5
dados.head(10) #podemos alterar para alem de 5
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         NaN     NaN
# 2   5200.0      4020.0  1111.0
# ...

# %% [markdown]
# Olhando para a parte final dos dados, tem mesma lógica acima.

# %%
dados.tail()
dados.tail(10)
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 32950              Apartamento                Tijuca        1      0       0
# 32951              Apartamento        Vila Valqueire        2      0       0
# 32952       Casa de Condomínio       Barra da Tijuca        5      3       4
# 32953              Apartamento                 Méier        2      0       0
# 32954              Box/Garagem                Centro        0      0       0
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area    Valor  Condominio    IPTU
# 32950    28   1000.0       360.0    25.0
# ...

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
dados.shape
# Out:
# (32960, 9)

# %%
dados.columns
# Out:
# Index(['Tipo', 'Bairro', 'Quartos', 'Vagas', 'Suites', 'Area', 'Valor',
#        'Condominio', 'IPTU'],
#       dtype='object')

# %% [markdown]
# analisando o tipo de dados em cada coluna

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
dados['Tipo'] #concluimos que os objetos ai sao strings
# Out:
# 0                      Quitinete
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                    Apartamento
# 4                    Apartamento
#                   ...
# 32955                  Quitinete
# 32956                Apartamento
# 32957                Apartamento
# 32958                Apartamento
# 32959    Conjunto Comercial/Sala
# Name: Tipo, Length: 32960, dtype: object

# %%
dados[['Quartos','Valor']]
# Out:
#        Quartos   Valor
# 0            1  1700.0
# 1            2  7000.0
# 2            0  5200.0
# 3            1   800.0
# 4            1   800.0
# ...        ...     ...
# 32955        0   800.0
# 32956        3  1800.0
# 32957        2  1400.0
# 32958        2  3000.0
# 32959        0  6500.0
#
# [32960 rows x 2 columns]

# %% [markdown]
# Pandas tem duas estruturas de dados
#
#
# -Series: É basicamente uma matriz de index e dados dos mais diversos tipos
# quando voce abriu dados['Tipo'] ela abriu uma series (lembra uma lista)
#
#
# -Dataframe: Aqui é quando lidamos com multiplas colunas também dos mais diversos tipos (aqui seria uma matriz)

# %% [markdown]
# Bloco 2

# %%
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
aluguel=  dados[['Tipo','Valor']]
aluguel
# Out:
#                           Tipo   Valor
# 0                    Quitinete  1700.0
# 1                         Casa  7000.0
# 2      Conjunto Comercial/Sala  5200.0
# 3                  Apartamento   800.0
# 4                  Apartamento   800.0
# ...                        ...     ...
# 32955                Quitinete   800.0
# 32956              Apartamento  1800.0
# 32957              Apartamento  1400.0
# 32958              Apartamento  3000.0
# 32959  Conjunto Comercial/Sala  6500.0
#
# [32960 rows x 2 columns]

# %%
aluguel['Tipo'].unique()
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %% [markdown]
# Ta vendo ai acima que tem varios tipos. Casas, apartamentos, quitinete etc... Precisamos de valores medios para cada tipo

# %%
dados.groupby('Tipo')[['Valor']].mean(numeric_only=True)
# Out:
#                                      Valor
# Tipo
# Apartamento                    4744.614648
# Box/Garagem                    1899.756098
# Casa                           6793.454922
# Casa Comercial                14478.264151
# Casa de Condomínio            11952.061245
# Casa de Vila                   1574.369478
# Chácara                        4900.000000
# Conjunto Comercial/Sala       14715.045521
# Flat                           4546.189076
# Galpão/Depósito/Armazém       53407.062600
# Hotel                         25000.000000
# Indústria                    120000.000000
# Loft                           2557.882353
# Loja Shopping/ Ct Comercial    8126.178862
# Loja/Salão                    13769.646770
# Loteamento/Condomínio         22000.000000
# Pousada/Chalé                  1480.000000
# Prédio Inteiro               498637.239203
# Quitinete                      1246.840909
# Studio                         2400.000000
# Sítio                         12499.000000
# ...

# %%
dados.groupby('Tipo')['Valor'].mean() # o interrsante que isso é uma series e o index é o tipo de imovel
# Out:
# Tipo
# Apartamento                      4744.614648
# Box/Garagem                      1899.756098
# Casa                             6793.454922
# Casa Comercial                  14478.264151
# Casa de Condomínio              11952.061245
# Casa de Vila                     1574.369478
# Chácara                          4900.000000
# Conjunto Comercial/Sala         14715.045521
# Flat                             4546.189076
# Galpão/Depósito/Armazém         53407.062600
# Hotel                           25000.000000
# Indústria                      120000.000000
# Loft                             2557.882353
# Loja Shopping/ Ct Comercial      8126.178862
# Loja/Salão                      13769.646770
# Loteamento/Condomínio           22000.000000
# Pousada/Chalé                    1480.000000
# Prédio Inteiro                 498637.239203
# Quitinete                        1246.840909
# Studio                           2400.000000
# Sítio                           12499.000000
# ...

# %%
dados.groupby('Tipo')[['Valor']].mean().sort_values('Valor') # Tem como fazer isso virar uma dataframe e a estrategia é sempre a mesma é botar mais um colchete e adicionar um ordenamento
# Out:
#                                      Valor
# Tipo
# Quitinete                      1246.840909
# Pousada/Chalé                  1480.000000
# Casa de Vila                   1574.369478
# Box/Garagem                    1899.756098
# Studio                         2400.000000
# Loft                           2557.882353
# Flat                           4546.189076
# Apartamento                    4744.614648
# Chácara                        4900.000000
# Casa                           6793.454922
# Loja Shopping/ Ct Comercial    8126.178862
# Casa de Condomínio            11952.061245
# Sítio                         12499.000000
# Loja/Salão                    13769.646770
# Casa Comercial                14478.264151
# Conjunto Comercial/Sala       14715.045521
# Loteamento/Condomínio         22000.000000
# Hotel                         25000.000000
# Terreno Padrão                32567.714286
# Galpão/Depósito/Armazém       53407.062600
# Indústria                    120000.000000
# ...

# %%
df_preco_tipo = dados.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
df_preco_tipo.plot(kind='barh',figsize=(14,10), color='purple')
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# Note que tem imoveis de todo tipo ai, mas precisamos dar uma limpada. Tirar, por exemplo, o imoveis comerceiais tipo Galpão, industria e hotel

# %%
dados.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %%
imoveis_comerciais = ['Conjunto Comercial/Sala','Prédio Inteiro','Loja/Salão','Galpão/Depósito/Armazém','Casa Comercial','Terreno Padrão','Loja Shopping/ Ct Comercial',
'Box/Garagem','Chácara','Loteamento/Condomínio','Sítio','Pousada/Chalé', 'Hotel', 'Indústria']

# %% [markdown]
# Metodo roubadissimo para remover esses elementos da base de dados Query, o Query permite selecionar linhas do dataframe com base em uma condição especifica

# %%
dados.query('@imoveis_comerciais in Tipo') # ele ta pegando a coluna tipos e buscando essa variavel ai. Por ser uma variavel temos que botar o @
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 2      Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 9      Conjunto Comercial/Sala           Centro        0      3       0   695
# 16              Prédio Inteiro         Botafogo        0      0       0   536
# 26     Conjunto Comercial/Sala    São Cristóvão        0      1       0    25
# 29                  Loja/Salão     Campo Grande        0      1       0    35
# ...                        ...              ...      ...    ...     ...   ...
# 32942  Conjunto Comercial/Sala  Barra da Tijuca        0      1       0    55
# 32946  Conjunto Comercial/Sala           Centro        0      0       0   140
# 32948  Conjunto Comercial/Sala           Centro        0      0       0    32
# 32954              Box/Garagem           Centro        0      0       0   755
# 32959  Conjunto Comercial/Sala           Centro        0      0       0   250
#
# ...

# %% [markdown]
# tirando os imoveis comerciais

# %%
df = dados.query('@imoveis_comerciais not in Tipo')

# %%
df.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Flat',
#        'Casa de Vila', 'Loft', 'Studio'], dtype=object)

# %%
df_preco_tipo = df.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
df_preco_tipo.plot(kind='barh',figsize=(14,10), color='purple')
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# Qual o percentual de cada tipo de imovel está presente em nosssa base de dados

# %%
df.Tipo.unique() #bora contar quantas vezes aparece cada amiguinho desse ai
df_percentual_tipo = df.Tipo.value_counts(normalize=True).to_frame().sort_values('proportion') #outro jeito de transformar em um dataframe

# %%
df_percentual_tipo
# Out:
#                     proportion
# Tipo
# Studio                0.000173
# Loft                  0.002207
# Casa de Vila          0.010774
# Flat                  0.020596
# Quitinete             0.036173
# Casa                  0.041842
# Casa de Condomínio    0.043096
# Apartamento           0.845139

# %%
df_percentual_tipo.plot(kind='bar',figsize=(14,10), color='green', xlabel = 'Tipos',ylabel = 'Percentual')
# Out:
# <Axes: xlabel='Tipos', ylabel='Percentual'>

# %% [markdown]
# Selecionando apenas apartamentos

# %%
df.query('Tipo == "Apartamento"') # O negócio é que apartamento precisa de aspas também kkk, nao existe a variavel apartamento indicando quais sao. Usamos aspas duplas para buscar dentro do dataframe
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# 6      Apartamento              Cachambi        2      0       0    50
# 10     Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 32951  Apartamento        Vila Valqueire        2      0       0    52
# 32953  Apartamento                 Méier        2      0       0    70
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 3       800.0       390.0  20.0
# 4       800.0       230.0   NaN
# ...

# %%
df = df.query('Tipo == "Apartamento"')
df.head()
# Out:
#            Tipo        Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3   Apartamento        Centro        1      0       0    15   800.0
# 4   Apartamento  Higienópolis        1      0       0    48   800.0
# 5   Apartamento  Vista Alegre        3      1       0    70  1200.0
# 6   Apartamento      Cachambi        2      0       0    50  1300.0
# 10  Apartamento        Centro        1      0       0    36  1200.0
#
#     Condominio  IPTU
# 3        390.0  20.0
# 4        230.0   NaN
# 5          NaN   NaN
# 6        301.0  17.0
# 10         NaN   NaN

# %% [markdown]
# Bloco 03

# %% [markdown]
# Bora limpar esses NaN, para isso devemos saber quais elementos da base de dados tem o NAN

# %%
df.isnull()
# Out:
#         Tipo  Bairro  Quartos  Vagas  Suites   Area  Valor  Condominio   IPTU
# 3      False   False    False  False   False  False  False       False  False
# 4      False   False    False  False   False  False  False       False   True
# 5      False   False    False  False   False  False  False        True   True
# 6      False   False    False  False   False  False  False       False  False
# 10     False   False    False  False   False  False  False        True   True
# ...      ...     ...      ...    ...     ...    ...    ...         ...    ...
# 32951  False   False    False  False   False  False  False       False   True
# 32953  False   False    False  False   False  False  False       False  False
# 32956  False   False    False  False   False  False  False       False  False
# 32957  False   False    False  False   False  False  False       False  False
# 32958  False   False    False  False   False  False  False       False   True
#
# [19532 rows x 9 columns]

# %% [markdown]
# Note que acima temos uma base de dados muito grande para ser analisada, precisamos compilar quantos valores sao nulos, no olho nessa tabela nao tem tanta informação.

# %%
df.isnull().sum()
# Out:
# Tipo             0
# Bairro           0
# Quartos          0
# Vagas            0
# Suites           0
# Area             0
# Valor            7
# Condominio     745
# IPTU          5472
# dtype: int64

# %% [markdown]
# A estrategia é transformar tudo que tem NAN em 0

# %%
df = df.fillna(0)#preenchendo tudo com 0

# %% [markdown]
# Conferindo

# %%
df.isnull().sum()
# Out:
# Tipo          0
# Bairro        0
# Quartos       0
# Vagas         0
# Suites        0
# Area          0
# Valor         0
# Condominio    0
# IPTU          0
# dtype: int64

# %% [markdown]
# Removendo registro inconsitentes

# %%
df.query('Valor == 0 | Condominio==0')
# Out:
#               Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 5      Apartamento     Vista Alegre        3      1       0    70  1200.0
# 10     Apartamento           Centro        1      0       0    36  1200.0
# 76     Apartamento  Barra da Tijuca        2      1       1    70     0.0
# 113    Apartamento       Praça Seca        2      0       0    80  1000.0
# 166    Apartamento    Rocha Miranda        2      1       0    50  1100.0
# ...            ...              ...      ...    ...     ...   ...     ...
# 32609  Apartamento       Copacabana        3      0       0   130  4600.0
# 32643  Apartamento        Guadalupe        1      0       0    40   550.0
# 32666  Apartamento       Bonsucesso        1      0       0    60  1000.0
# 32708  Apartamento         Flamengo        2      0       0    59  3500.0
# 32809  Apartamento        Cascadura        3      0       1    70  1200.0
#
#        Condominio  IPTU
# 5             0.0   0.0
# 10            0.0   0.0
# ...

# %%
registros_a_remover =df.query('Valor == 0 | Condominio==0').index #index dos valores nulos

# %%
df.drop(registros_a_remover, axis=0,inplace=True)

# %%
df.query('Valor == 0 | Condominio==0')
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %%
df.drop('Tipo',axis=1,inplace=True)

# %% [markdown]
# Filtros. Apartamento de 1 quarto com aluguel < 1200

# %%
df['Quartos']==1
# Out:
# 3         True
# 4         True
# 6        False
# 11       False
# 12       False
#          ...
# 32951    False
# 32953    False
# 32956    False
# 32957    False
# 32958    False
# Name: Quartos, Length: 18780, dtype: bool

# %%
selecao1 = df['Quartos']==1
df[selecao1]
# Out:
#                 Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 3               Centro        1      0       0    15   800.0       390.0
# 4         Higienópolis        1      0       0    48   800.0       230.0
# 13          Copacabana        1      0       1    40  2000.0       561.0
# 28              Tijuca        1      0       0    48   750.0       772.0
# 54              Centro        1      0       0    27   750.0       371.0
# ...                ...      ...    ...     ...   ...     ...         ...
# 32918          Ipanema        1      0       0    55  2000.0       630.0
# 32922  Barra da Tijuca        1      1       0    62  1700.0       945.0
# 32935           Leblon        1      1       1    50  4300.0      1730.0
# 32938       Copacabana        1      0       0    50  1950.0       450.0
# 32950           Tijuca        1      0       0    28  1000.0       360.0
#
#         IPTU
# 3       20.0
# 4        0.0
# 13      50.0
# 28      25.0
# 54      19.0
# ...

# %%
df['Valor']<1200
# Out:
# 3         True
# 4         True
# 6        False
# 11       False
# 12       False
#          ...
# 32951     True
# 32953     True
# 32956    False
# 32957    False
# 32958    False
# Name: Valor, Length: 18780, dtype: bool

# %%
selecao2= df['Valor']<1200
df[selecao2]
# Out:
#                         Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3                       Centro        1      0       0    15   800.0
# 4                 Higienópolis        1      0       0    48   800.0
# 19     Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 23                      Olaria        3      1       0    68  1000.0
# 28                      Tijuca        1      0       0    48   750.0
# ...                        ...      ...    ...     ...   ...     ...
# 32925                 Campinho        2      0       0    63   800.0
# 32930  Freguesia (Jacarepaguá)        2      1       0    60   500.0
# 32950                   Tijuca        1      0       0    28  1000.0
# 32951           Vila Valqueire        2      0       0    52  1000.0
# 32953                    Méier        2      0       0    70   900.0
#
#        Condominio   IPTU
# 3           390.0   20.0
# 4           230.0    0.0
# 19          300.0   28.0
# 23          670.0    0.0
# ...

# %%
selecao_geral = (selecao1) & (selecao2)==1
df[selecao_geral]
# Out:
#              Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio   IPTU
# 3            Centro        1      0       0    15   800.0       390.0   20.0
# 4      Higienópolis        1      0       0    48   800.0       230.0    0.0
# 28           Tijuca        1      0       0    48   750.0       772.0   25.0
# 54           Centro        1      0       0    27   750.0       371.0   19.0
# 94           Centro        1      1       0    37  1100.0       540.0  900.0
# ...             ...      ...    ...     ...   ...     ...         ...    ...
# 32596        Grajaú        1      0       1    37  1000.0       200.0    0.0
# 32617     Pechincha        1      0       1    69   900.0       640.0  126.0
# 32627        Glória        1      0       0    46  1100.0       453.0   32.0
# 32714      Botafogo        1      0       0    21  1000.0       282.0   25.0
# 32950        Tijuca        1      0       0    28  1000.0       360.0   25.0
#
# [499 rows x 8 columns]

# %%
df_1 = df[selecao_geral]

# %% [markdown]
# 2. Apartamentos que possuem pelo menos 2 quartos, aluguel menor que R$ 3000 e área maior que 70 m².

# %%
selecao_geral2 = (df['Quartos']>= 2) & (df['Valor']<3000) & (df['Area']>70)
df_2 = df[selecao_geral2]

# %% [markdown]
# Salvando dados

# %%
df.to_csv('dados_apartamento.csv')

# %% [markdown]
# Ele cria novos indices e os indices antigos se tornam uma coluna

# %%
pd.read_csv('dados_apartamento.csv')
# Out:
#        Unnamed: 0                Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0               3                Centro        1      0       0    15   800.0
# 1               4          Higienópolis        1      0       0    48   800.0
# 2               6              Cachambi        2      0       0    50  1300.0
# 3              11                Grajaú        2      1       0    70  1500.0
# 4              12   Lins de Vasconcelos        3      1       1    90  1500.0
# ...           ...                   ...      ...    ...     ...   ...     ...
# 18775       32951        Vila Valqueire        2      0       0    52  1000.0
# 18776       32953                 Méier        2      0       0    70   900.0
# 18777       32956           Jacarepaguá        3      1       2    78  1800.0
# 18778       32957  São Francisco Xavier        2      1       0    48  1400.0
# 18779       32958                Leblon        2      0       0    70  3000.0
#
#        Condominio  IPTU
# ...

# %%
df.to_csv('dados_apartamento.csv',index=False)

# %%
pd.read_csv('dados_apartamento.csv')
# Out:
#                      Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 0                    Centro        1      0       0    15   800.0       390.0
# 1              Higienópolis        1      0       0    48   800.0       230.0
# 2                  Cachambi        2      0       0    50  1300.0       301.0
# 3                    Grajaú        2      1       0    70  1500.0       642.0
# 4       Lins de Vasconcelos        3      1       1    90  1500.0       455.0
# ...                     ...      ...    ...     ...   ...     ...         ...
# 18775        Vila Valqueire        2      0       0    52  1000.0       550.0
# 18776                 Méier        2      0       0    70   900.0       490.0
# 18777           Jacarepaguá        3      1       2    78  1800.0       800.0
# 18778  São Francisco Xavier        2      1       0    48  1400.0       509.0
# 18779                Leblon        2      0       0    70  3000.0       760.0
#
#        IPTU
# 0      20.0
# ...

# %%
df.to_csv('dados_apartamento.csv',index=False,sep=';')

# %%
pd.read_csv('dados_apartamento.csv',sep=';')
# Out:
#                      Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 0                    Centro        1      0       0    15   800.0       390.0
# 1              Higienópolis        1      0       0    48   800.0       230.0
# 2                  Cachambi        2      0       0    50  1300.0       301.0
# 3                    Grajaú        2      1       0    70  1500.0       642.0
# 4       Lins de Vasconcelos        3      1       1    90  1500.0       455.0
# ...                     ...      ...    ...     ...   ...     ...         ...
# 18775        Vila Valqueire        2      0       0    52  1000.0       550.0
# 18776                 Méier        2      0       0    70   900.0       490.0
# 18777           Jacarepaguá        3      1       2    78  1800.0       800.0
# 18778  São Francisco Xavier        2      1       0    48  1400.0       509.0
# 18779                Leblon        2      0       0    70  3000.0       760.0
#
#        IPTU
# 0      20.0
# ...

# %% [markdown]
# ## (DEV_Demands) | bloco 4 | Precisamos retomar todo o banco de dados

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
dados = pd.read_csv(url,sep=';')

# %%
dados['Valor_por_mes']= dados['Valor'] + dados['Condominio']
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes
# 0  1700.0       500.0    60.0         2200.0
# 1  7000.0         NaN     NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0
# 3   800.0       390.0    20.0         1190.0
# 4   800.0       230.0     NaN         1030.0

# %%
dados['Valor_por_ano'] = (12 * dados['Valor_por_mes']) + dados['IPTU']
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes  Valor_por_ano
# 0  1700.0       500.0    60.0         2200.0        26460.0
# 1  7000.0         NaN     NaN            NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0       111751.0
# 3   800.0       390.0    20.0         1190.0        14300.0
# 4   800.0       230.0     NaN         1030.0            NaN

# %% [markdown]
# colunas_categoricas

# %%
dados['Descricao'] = dados['Tipo'] + ' em ' + dados['Bairro'] + ' com '+ dados['Quartos'].astype(str) \
+ ' quarto (s) ' +' e ' + dados['Vagas'].astype(str) + ' Vagas de garagem. '
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes  Valor_por_ano  \
# 0  1700.0       500.0    60.0         2200.0        26460.0
# 1  7000.0         NaN     NaN            NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0       111751.0
# 3   800.0       390.0    20.0         1190.0        14300.0
# 4   800.0       230.0     NaN         1030.0            NaN
#
#                                            Descricao
# 0  Quitinete em Copacabana com 1 quarto (s)  e 0 ...
# ...

# %% [markdown]
# Cria coluna com condiçao

# %%
dados['Possui_suite'] = dados['Suites'].apply( lambda x: 'Sim' if x>0 else 'Não' )
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes  Valor_por_ano  \
# 0  1700.0       500.0    60.0         2200.0        26460.0
# 1  7000.0         NaN     NaN            NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0       111751.0
# 3   800.0       390.0    20.0         1190.0        14300.0
# 4   800.0       230.0     NaN         1030.0            NaN
#
#                                            Descricao Possui_suite
# 0  Quitinete em Copacabana com 1 quarto (s)  e 0 ...          Não
# ...

# %%
dados.to_csv('Dados_completos_dev.csv',sep=';',index=False)

# %% [markdown]
# #Desafio

# %%
url_desafio = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'
dados_desafio = pd.read_csv(url_desafio)

# %%
dados_desafio.head(8)
# Out:
#      Nome  Idade  Notas  Aprovado
# 0     Ary     20    7.5      True
# 1     Ana     18    NaN     False
# 2   Cátia     27    2.5     False
# 3   Denis     18    5.0     False
# 4    Beto     21   10.0      True
# 5   Bruna     23    NaN     False
# 6    Dara     21    7.0      True
# 7  Carlos     19    6.0      True

# %%
dados_desafio.tail(5)
# Out:
#       Nome  Idade  Notas  Aprovado
# 13   Mirla     25    9.0      True
# 14   Paulo     37    NaN     False
# 15  Mylena     29    7.0      True
# 16   Lucas     33    NaN     False
# 17   Nadia     34    8.0      True

# %%
dados_desafio.shape #18linha e 4 colunas
# Out:
# (18, 4)

# %%
dados_desafio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nome      18 non-null     object
#  1   Idade     18 non-null     int64
#  2   Notas     12 non-null     float64
#  3   Aprovado  18 non-null     bool
# dtypes: bool(1), float64(1), int64(1), object(1)
# memory usage: 582.0+ bytes

# %%
dados_desafio['Nome'] # object = sstring
# Out:
# 0           Ary
# 1           Ana
# 2         Cátia
# 3         Denis
# 4          Beto
# 5         Bruna
# 6          Dara
# 7        Carlos
# 8         Alice
# 9         Vitor
# 10       Daniel
# 11         Igor
# 12    Sthefanie
# 13        Mirla
# 14        Paulo
# 15       Mylena
# 16        Lucas
# 17        Nadia
# Name: Nome, dtype: object

# %%
dados_desafio[['Idade','Notas']]
# Out:
#     Idade  Notas
# 0      20    7.5
# 1      18    NaN
# 2      27    2.5
# 3      18    5.0
# 4      21   10.0
# 5      23    NaN
# 6      21    7.0
# 7      19    6.0
# 8      35    5.6
# 9      28    NaN
# 10     21    NaN
# 11     24    4.5
# 12     26    9.5
# 13     25    9.0
# 14     37    NaN
# 15     29    7.0
# 16     33    NaN
# 17     34    8.0

# %%
nomes= dados_desafio['Nome']
idade = dados_desafio['Idade']
notas = dados_desafio['Notas']
aprovacao=dados_desafio['Aprovado']

# %%
idade_media = idade.mean()
notas_medias = notas.mean()

# %%
std_age = idade.std()
std_nota= idade.std()

# %% [markdown]
# Ou de maneira mais fácil que esses 4 comandos podemos utilizzar o metodo info

# %%
dados_desafio.describe()
# Out:
#            Idade      Notas
# count  18.000000  12.000000
# mean   25.500000   6.800000
# std     6.070662   2.204953
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %% [markdown]
# 1) Verifique se a base de dados possui dados nulos e, caso tenha, realize o tratamento desses dados nulos da forma que achar mais coerente com a situação.

# %%
dados_desafio.isnull().sum()
# Out:
# Nome        0
# Idade       0
# Notas       6
# Aprovado    0
# dtype: int64

# %%
dados_desafio.fillna(0, inplace=True)

# %%
dados_desafio
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# registros_a_remover =df.query('Valor == 0 | Condominio==0').index #index dos valores nulos

# %%
registros_remover_desafio = dados_desafio.query('Notas == 0').index

# %% [markdown]
# Drop agora isso

# %%
dados_desafio.drop(registros_remover_desafio,axis=0, inplace=True)

# %%
dados_desafio.isnull().sum()
# Out:
# Nome        0
# Idade       0
# Notas       0
# Aprovado    0
# dtype: int64

# %% [markdown]
# 2) Os alunos "Alice" e "Carlos", não fazem mais parte da turma. Sendo assim, remova-os da base de dados.

# %%
registro_aluno_remocao = dados_desafio.query('Nome == "Carlos"').index

# %%
dados_desafio.drop(registro_aluno_remocao,inplace=True, axis=0)

# %% [markdown]
# 3) Aplique um filtro que selecione apenas os alunos que foram aprovados. registros_a_remover =df.query('Valor == 0 | Condominio==0').index #index dos valores nulos

# %%
index_reprovados = dados_desafio.query('Aprovado == False').index
index_reprovados
# Out:
# Index([2, 3, 8, 11], dtype='int64')

# %%
dados_desafio.drop(index_reprovados,axis=0, inplace=True)

# %%
type(dados_desafio)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# 4) Salve o DataFrame que possui apenas os alunos aprovados em um arquivo csv chamado "alunos_aprovados.csv".

# %%
dados_desafio.to_csv('alunos_aprovados.csv',index=False,sep=',')

# %% [markdown]
# Extra: Ao conferir as notas dos alunos aprovados, notamos que algumas notas estavam incorretas. As alunas que tiraram nota 7.0, na verdade, tinham um ponto extra que não foi contabilizado. Sendo assim, substitua as notas 7.0 da base de dados por 8.0. Dica: pesquise pelo método replace.

# %%
dados_desafio
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    7.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    7.0      True
# 17      Nadia     34    8.0      True

# %%
dados_desafio = dados_desafio.replace(7.0,8.0)

# %%
dados_desafio.to_csv('Alunos_aprovados',index=False,sep=',')

# %% [markdown]
# Desafio_de_ultima_hora

# %% [markdown]
# -Calcular a média de quartos de todos os imóveis;

# %%
dados['Quartos'].mean()
# Out:
# 1.7713895631067962

# %% [markdown]
# -Conferir quantos bairros únicos existem na nossa base de dados;

# %%
Quant_bairro_unico= dados['Bairro'].nunique()
Quant_bairro_unico
# Out:
# 162

# %% [markdown]
# 3) Analisar quais bairros possuem a média de valor de aluguel mais elevadas;

# %%
bairros_mais_caros =dados.groupby('Bairro')[['Valor']].mean().sort_values('Valor',ascending =False).head()

# %% [markdown]
# 4) Criar um gráfico de barras horizontais que apresente os 5 bairros com as médias de valores de aluguel mais elevadas.

# %%
bairros_mais_caros.plot(kind='bar',figsize=(14,10), color='green', xlabel = '',ylabel = '')
# Out:
# <Axes: >

# %% [markdown]
# salvando o df_1, e d_f2 em files

# %%
df_1
# Out:
#              Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio   IPTU
# 3            Centro        1      0       0    15   800.0       390.0   20.0
# 4      Higienópolis        1      0       0    48   800.0       230.0    0.0
# 28           Tijuca        1      0       0    48   750.0       772.0   25.0
# 54           Centro        1      0       0    27   750.0       371.0   19.0
# 94           Centro        1      1       0    37  1100.0       540.0  900.0
# ...             ...      ...    ...     ...   ...     ...         ...    ...
# 32596        Grajaú        1      0       1    37  1000.0       200.0    0.0
# 32617     Pechincha        1      0       1    69   900.0       640.0  126.0
# 32627        Glória        1      0       0    46  1100.0       453.0   32.0
# 32714      Botafogo        1      0       0    21  1000.0       282.0   25.0
# 32950        Tijuca        1      0       0    28  1000.0       360.0   25.0
#
# [499 rows x 8 columns]

# %%
df_1.to_csv('Data_frame_1Quarto_menos1200', index=False,sep=';')

# %%
df_2.to_csv('Data_frame_2selecao', index=False,sep=';')

# %%
pd.read_csv('Data_frame_1Quarto_menos1200',sep=';')
# Out:
#            Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio   IPTU
# 0          Centro        1      0       0    15   800.0       390.0   20.0
# 1    Higienópolis        1      0       0    48   800.0       230.0    0.0
# 2          Tijuca        1      0       0    48   750.0       772.0   25.0
# 3          Centro        1      0       0    27   750.0       371.0   19.0
# 4          Centro        1      1       0    37  1100.0       540.0  900.0
# ..            ...      ...    ...     ...   ...     ...         ...    ...
# 494        Grajaú        1      0       1    37  1000.0       200.0    0.0
# 495     Pechincha        1      0       1    69   900.0       640.0  126.0
# 496        Glória        1      0       0    46  1100.0       453.0   32.0
# 497      Botafogo        1      0       0    21  1000.0       282.0   25.0
# 498        Tijuca        1      0       0    28  1000.0       360.0   25.0
#
# [499 rows x 8 columns]

# %%
pd.read_csv('Data_frame_2selecao',sep=';')
# Out:
#                         Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0          Lins de Vasconcelos        3      1       1    90  1500.0
# 1                       Tijuca        2      1       0   110  1900.0
# 2                       Tijuca        2      1       0    78  2000.0
# 3                     Botafogo        2      1       0    76  2500.0
# 4     Recreio dos Bandeirantes        3      1       1   105  2300.0
# ...                        ...      ...    ...     ...   ...     ...
# 4454               Jacarepaguá        2      1       1    78  2200.0
# 4455           Barra da Tijuca        2      1       1    85  2250.0
# 4456           Barra da Tijuca        3      2       0    98  2300.0
# 4457  Recreio dos Bandeirantes        3      2       1    88  1550.0
# 4458               Jacarepaguá        3      1       2    78  1800.0
#
#       Condominio   IPTU
# 0          455.0   14.0
# 1          700.0  138.0
# 2          700.0    0.0
# 3          740.0    0.0
# ...

# %% [markdown]
# 1) Os alunos participaram de uma atividade extracurricular e ganharam pontos extras. Esses pontos extras correspondem a 40% da nota atual de cada um deles. Com base nisso, crie uma coluna chamada "Pontos_extras" que contenha os pontos extras de cada aluno, ou seja, 40% da nota atual deles.

# %%
url_des_final = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'
df_des_final = pd.read_csv(url_des_final,sep=',')
df_des_final
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# Tratanddo o NaN | dados_desafio.fillna(0, inplace=True)

# %%
df_des_final.fillna(0,inplace=True)

# %%
df_des_final
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# Lembrando que o Carlos e a alice droparam da turma

# %%
alunos_a_remover = df_des_final.query('Nome == "Alice" | Nome == "Carlos"').index
alunos_a_remover
# Out:
# Index([7, 8], dtype='int64')

# %%
df_des_final.drop(alunos_a_remover,axis=0,inplace=True)
df_des_final
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# Agora vc precisa substituir onde tem 7 por 8

# %%
df_des_final.replace(7.0,8.0, inplace=True)
df_des_final
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    8.0      True
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    8.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %%
df_des_final['Ponto Extra'] = df_des_final['Notas']*0.4
df_des_final
# Out:
#          Nome  Idade  Notas  Aprovado  Ponto Extra
# 0         Ary     20    7.5      True          3.0
# 1         Ana     18    0.0     False          0.0
# 2       Cátia     27    2.5     False          1.0
# 3       Denis     18    5.0     False          2.0
# 4        Beto     21   10.0      True          4.0
# 5       Bruna     23    0.0     False          0.0
# 6        Dara     21    8.0      True          3.2
# 9       Vitor     28    0.0     False          0.0
# 10     Daniel     21    0.0     False          0.0
# 11       Igor     24    4.5     False          1.8
# 12  Sthefanie     26    9.5      True          3.8
# 13      Mirla     25    9.0      True          3.6
# 14      Paulo     37    0.0     False          0.0
# 15     Mylena     29    8.0      True          3.2
# 16      Lucas     33    0.0     False          0.0
# 17      Nadia     34    8.0      True          3.2

# %%
df_des_final['Nota_final'] = df_des_final['Notas'] + df_des_final['Ponto Extra']
df_des_final
# Out:
#          Nome  Idade  Notas  Aprovado  Ponto Extra  Nota_final
# 0         Ary     20    7.5      True          3.0        10.5
# 1         Ana     18    0.0     False          0.0         0.0
# 2       Cátia     27    2.5     False          1.0         3.5
# 3       Denis     18    5.0     False          2.0         7.0
# 4        Beto     21   10.0      True          4.0        14.0
# 5       Bruna     23    0.0     False          0.0         0.0
# 6        Dara     21    8.0      True          3.2        11.2
# 9       Vitor     28    0.0     False          0.0         0.0
# 10     Daniel     21    0.0     False          0.0         0.0
# 11       Igor     24    4.5     False          1.8         6.3
# 12  Sthefanie     26    9.5      True          3.8        13.3
# 13      Mirla     25    9.0      True          3.6        12.6
# 14      Paulo     37    0.0     False          0.0         0.0
# 15     Mylena     29    8.0      True          3.2        11.2
# ...

# %%
df_des_final['Nota_final'] = df_des_final['Nota_final'].apply( lambda x : 10 if x>10 else x)
df_des_final
# Out:
#          Nome  Idade  Notas  Aprovado  Ponto Extra  Nota_final
# 0         Ary     20    7.5      True          3.0        10.0
# 1         Ana     18    0.0     False          0.0         0.0
# 2       Cátia     27    2.5     False          1.0         3.5
# 3       Denis     18    5.0     False          2.0         7.0
# 4        Beto     21   10.0      True          4.0        10.0
# 5       Bruna     23    0.0     False          0.0         0.0
# 6        Dara     21    8.0      True          3.2        10.0
# 9       Vitor     28    0.0     False          0.0         0.0
# 10     Daniel     21    0.0     False          0.0         0.0
# 11       Igor     24    4.5     False          1.8         6.3
# 12  Sthefanie     26    9.5      True          3.8        10.0
# 13      Mirla     25    9.0      True          3.6        10.0
# 14      Paulo     37    0.0     False          0.0         0.0
# 15     Mylena     29    8.0      True          3.2        10.0
# ...

# %% [markdown]
# 3) Como houve uma pontuação extra, alguns alunos que não tinham sido aprovados antes podem ter sido aprovados agora. Com base nisso, crie uma coluna chamada "Aprovado_final" com os seguintes valores:
#
# True: caso o aluno esteja aprovado (nota final deve ser maior ou igual a 6);
#
# False: caso o aluno esteja reprovado (nota final deve ser menor que 6) .

# %%
df_des_final['Aprovado_final'] = df_des_final['Nota_final'].apply( lambda x : 'Sim' if x>=6 else 'Não')
df_des_final
# Out:
#          Nome  Idade  Notas  Aprovado  Ponto Extra  Nota_final Aprovado_final
# 0         Ary     20    7.5      True          3.0        10.0            Sim
# 1         Ana     18    0.0     False          0.0         0.0            Não
# 2       Cátia     27    2.5     False          1.0         3.5            Não
# 3       Denis     18    5.0     False          2.0         7.0            Sim
# 4        Beto     21   10.0      True          4.0        10.0            Sim
# 5       Bruna     23    0.0     False          0.0         0.0            Não
# 6        Dara     21    8.0      True          3.2        10.0            Sim
# 9       Vitor     28    0.0     False          0.0         0.0            Não
# 10     Daniel     21    0.0     False          0.0         0.0            Não
# 11       Igor     24    4.5     False          1.8         6.3            Sim
# 12  Sthefanie     26    9.5      True          3.8        10.0            Sim
# ...

# %% [markdown]
# 4) Faça uma seleção e verifique quais alunos não tinham sido aprovados anteriormente, mas foram aprovados após a soma dos pontos extras.

# %%
Alunos_salvos = df_des_final.query('Notas  < 6 & Aprovado_final == "Sim" ').index
Alunos_salvos
# Out:
# Index([3, 11], dtype='int64')

# %%
df_des_final.query('Aprovado == False & Aprovado_final == "Sim"').index
# Out:
# Index([3, 11], dtype='int64')
